# %% [markdown]
# # Preprocessing for Heart data

# %% [markdown]
# # Step1: Import data

# %%
import pandas as pd
import numpy as np
df=pd.read_excel('D:/3rd Session/Data/Heart data.xlsx')

# %%
df=pd.read_csv('D:/3rd Session/Data/Heart data.xlsx')

# %%
df.shape
# Out:
# (597, 14)

# %%
df.describe()      # اطلاعات آماری درباره هر ستون
# Out:
#        Age (age in year)         sex  chest pain  blood pressure  \
# count         597.000000  597.000000  597.000000      596.000000
# mean           51.182580    0.701843    3.072027      132.129195
# std             9.074366    0.457833    0.965776       17.603812
# min            28.000000    0.000000    1.000000       92.000000
# 25%            44.000000    0.000000    2.000000      120.000000
# 50%            52.000000    1.000000    3.000000      130.000000
# 75%            58.000000    1.000000    4.000000      140.000000
# max            77.000000    1.000000    4.000000      200.000000
#
#        cholestoral   blood sugar  electrocardiographic   heart rate  \
# count    574.000000   589.000000             596.000000  596.000000
# mean     248.655052     0.110357               0.610738  144.456376
# std       59.784805     0.313600               0.869358   23.794282
# min       85.000000     0.000000               0.000000   71.000000
# ...

# %%
df.columns     
#اسم ستون ها رو میاره و باعث جلوگیری از خطاهای تایپی شویم
# Out:
# Index(['Age (age in year)', 'sex', 'chest pain', 'blood pressure',
#        'cholestoral ', 'blood sugar', 'electrocardiographic ', 'heart rate',
#        'exercise induced', 'depression ', 'slope', 'ca', 'thal', 'c'],
#       dtype='object')

# %%
print(df.min())
print(df.max())
print(df.mean())
print(df.median())
print(df.std())
# Out:
# Age (age in year)        28.0
# sex                       0.0
# chest pain                1.0
# blood pressure           92.0
# cholestoral              85.0
# blood sugar               0.0
# electrocardiographic      0.0
# heart rate               71.0
# exercise induced          0.0
# depression                0.0
# slope                     1.0
# ca                        0.0
# thal                      3.0
# c                         0.0
# dtype: float64
# Age (age in year)         77.0
# sex                        1.0
# chest pain                 4.0
# blood pressure           200.0
# cholestoral              603.0
# blood sugar                1.0
# electrocardiographic       2.0
# heart rate               202.0
# exercise induced           1.0
# depression                 6.2
# slope                      3.0
# ca                         9.0
# thal                       7.0
# c                          1.0
# dtype: float64
# Age (age in year)         51.182580
# ...

# %%
df.corr()
# Out:
#                        Age (age in year)       sex  chest pain  \
# Age (age in year)               1.000000 -0.062397    0.147064
# sex                            -0.062397  1.000000    0.120748
# chest pain                      0.147064  0.120748    1.000000
# blood pressure                  0.238490  0.010620    0.021586
# cholestoral                     0.123624 -0.076399    0.104111
# blood sugar                     0.176286  0.038030    0.001428
# electrocardiographic            0.260132 -0.034982    0.073320
# heart rate                     -0.303596 -0.088691   -0.322748
# exercise induced                0.155862  0.148814    0.438328
# depression                      0.253305  0.095716    0.277695
# slope                           0.078979  0.075835    0.209141
# ca                              0.303705  0.039879    0.227391
# thal                            0.105296  0.349134    0.245214
# c                               0.216430  0.268343    0.463527
#
# ...

# %%
df['c']      #ستون خاصی را نمایش دهد
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 592    1
# 593    1
# 594    1
# 595    1
# 596    1
# Name: c, Length: 597, dtype: int64

# %%
df.c    #درون اسم ستون فقط نباید فاصله باشد اگر نه از _ استفاده کنیم
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 592    1
# 593    1
# 594    1
# 595    1
# 596    1
# Name: c, Length: 597, dtype: int64

# %%
df.sort_values('chest pain')  
# به صورت پیش فرض به صورت صعودی
# Out:
#      Age (age in year)  sex  chest pain  blood pressure  cholestoral   \
# 0                   63    1           1           145.0         233.0
# 152                 64    1           1           170.0         227.0
# 405                 45    1           1           110.0         264.0
# 24                  40    1           1           140.0         199.0
# 101                 59    1           1           178.0         270.0
# ..                 ...  ...         ...             ...           ...
# 384                 57    1           4           152.0         274.0
# 383                 59    0           4           174.0         249.0
# 382                 35    1           4           126.0         282.0
# 351                 53    1           4           130.0         182.0
# 596                 49    1           4           150.0         222.0
#
#      blood sugar  electrocardiographic   heart rate  exercise induced  \
# ...

# %%
df.sort_values('chest pain',ascending=False)
# Out:
#      Age (age in year)  sex  chest pain  blood pressure  cholestoral   \
# 596                 49    1           4           150.0         222.0
# 252                 53    1           4           140.0         243.0
# 260                 55    1           4           120.0         270.0
# 481                 52    1           4           120.0         182.0
# 482                 55    1           4           140.0         268.0
# ..                 ...  ...         ...             ...           ...
# 100                 42    1           1           148.0         244.0
# 562                 55    1           1           140.0         295.0
# 83                  52    1           1           152.0         298.0
# 485                 43    1           1           120.0         291.0
# 0                   63    1           1           145.0         233.0
#
#      blood sugar  electrocardiographic   heart rate  exercise induced  \
# ...

# %%
df['chest pain']>2
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4       True
#        ...
# 592     True
# 593     True
# 594     True
# 595     True
# 596     True
# Name: chest pain, Length: 597, dtype: bool

# %%
#تعداد سطر و ستونی که مقادیر درد سینه بیش از 2 است را نشان می دهد
mydata=df[df['chest pain']>2]
mydata.shape
# Out:
# (407, 14)

# %%
df['chest pain']  [df['chest pain']>2]
# df[column name] [df[logic]] 

 #مقادیر را نشان می دهد نه درست بودن یا نبودن
# Out:
# 1      3
# 4      4
# 5      4
# 8      3
# 9      3
#       ..
# 592    4
# 593    4
# 594    4
# 595    4
# 596    4
# Name: chest pain, Length: 407, dtype: int64

# %%
mydata=df[(df['chest pain']>2)& df['sex']==1]
mydata.shape
# Out:
# (297, 14)

# %% [markdown]
# # Step 2: Data Manipulation

# %%
df=df.rename(columns={'Age (age in year)':'age','cholestoral ':'ch'})
df



#حواست به اسپیس ها باشه
# Out:
#      age  sex  chest pain  blood pressure  cholestoral   blood sugar  \
# 0     63    1           1           145.0         233.0          1.0
# 1     37    1           3           130.0         250.0          0.0
# 2     41    0           2           130.0         204.0          0.0
# 3     56    1           2           120.0         236.0          0.0
# 4     57    0           4           120.0         354.0          0.0
# ..   ...  ...         ...             ...           ...          ...
# 592   52    1           4           140.0         266.0          0.0
# 593   43    1           4           140.0         288.0          0.0
# 594   41    1           4           120.0         336.0          0.0
# 595   44    1           4           135.0         491.0          0.0
# 596   49    1           4           150.0         222.0          0.0
#
#      electrocardiographic   heart rate  exercise induced  depression   slope  \
# ...

# %%
df.dtypes
# Out:
# age                        int64
# sex                        int64
# chest pain                 int64
# blood pressure           float64
# ch                       float64
# blood sugar              float64
# electrocardiographic     float64
# heart rate               float64
# exercise induced         float64
# depression               float64
# slope                    float64
# ca                       float64
# thal                     float64
# c                          int64
# dtype: object

# %%
df1 = df.select_dtypes(include = 'object')
df2 = df.select_dtypes(exclude = 'object')
df2.head()
# Out:
#    age  sex  chest pain  blood pressure     ch  blood sugar  \
# 0   63    1           1           145.0  233.0          1.0
# 1   37    1           3           130.0  250.0          0.0
# 2   41    0           2           130.0  204.0          0.0
# 3   56    1           2           120.0  236.0          0.0
# 4   57    0           4           120.0  354.0          0.0
#
#    electrocardiographic   heart rate  exercise induced  depression   slope  \
# 0                    2.0       150.0               0.0          2.3    3.0
# 1                    0.0       187.0               0.0          3.5    3.0
# 2                    2.0       172.0               0.0          1.4    1.0
# 3                    0.0       178.0               0.0          0.8    1.0
# 4                    0.0       163.0               1.0          0.6    1.0
#
#     ca  thal  c
# 0  0.0   6.0  0
# 1  0.0   3.0  0
# 2  0.0   3.0  0
# 3  0.0   3.0  0
# 4  0.0   3.0  0

# %%
df.iloc[200:300,:].head(3)
# Out:
#      age  sex  chest pain  blood pressure     ch  blood sugar  \
# 200   52    0           4           130.0  180.0          0.0
# 201   51    0           2           160.0  194.0          0.0
# 202   54    1           4           150.0  365.0          0.0
#
#      electrocardiographic   heart rate  exercise induced  depression   slope  \
# 200                    0.0       140.0               1.0          1.5    2.0
# 201                    0.0       170.0               0.0          0.0    NaN
# 202                    1.0       134.0               0.0          1.0    1.0
#
#      ca  thal  c
# 200 NaN   NaN  0
# 201 NaN   NaN  0
# 202 NaN   NaN  0

# %%
df.iloc[200:300,4:8]

#data cutting
# Out:
#      cholestoral   blood sugar  electrocardiographic   heart rate
# 200         180.0          0.0                    0.0       140.0
# 201         194.0          0.0                    0.0       170.0
# 202         365.0          0.0                    1.0       134.0
# 203         253.0          0.0                    0.0       174.0
# 204           NaN          0.0                    0.0       175.0
# ..            ...          ...                    ...         ...
# 295         219.0          0.0                    1.0       150.0
# 296         184.0          0.0                    0.0       100.0
# 297         215.0          0.0                    0.0       140.0
# 298         308.0          0.0                    2.0       180.0
# 299         132.0          0.0                    2.0       185.0
#
# [100 rows x 4 columns]

# %% [markdown]
# # Balanced? Imbalanced?

# %%
df['c'].value_counts()
# Out:
# 0    352
# 1    245
# Name: c, dtype: int64

# %%
df['chest pain'].value_counts()   #تعداد در انواع حالات درد قفسه سینه
# Out:
# 4    267
# 2    156
# 3    140
# 1     34
# Name: chest pain, dtype: int64

# %%
df['ch'].value_counts()
# Out:
# 246.0    8
# 211.0    8
# 230.0    8
# 254.0    7
# 275.0    7
#         ..
# 417.0    1
# 339.0    1
# 347.0    1
# 327.0    1
# 174.0    1
# Name: ch, Length: 201, dtype: int64

# %%
df_corr=df.corr()['c'][:-1]
feature_list=df_corr[df_corr>0.1].sort_values(ascending=False)
feature_list
# Out:
# c                        1.000000
# chest pain_4             0.537123
# chest pain_4             0.537123
# exercise induced         0.504280
# depression               0.481305
# slope_2.0                0.476831
# ca                       0.383576
# sex                      0.268343
# age                      0.216430
# ch                       0.145802
# blood pressure           0.142178
# electrocardiographic     0.137410
# thal_6.0                 0.104837
# Name: c, dtype: float64

# %%
import pandas as pd
pd.crosstab(df.ch,df.sex)      #دو متغیر را بر اساس همدیگر بنویسم
# Out:
# sex    0  1
# ch
# 85.0   0  1
# 100.0  0  1
# 117.0  0  1
# 126.0  0  1
# 129.0  0  1
# ...   .. ..
# 491.0  0  1
# 518.0  0  1
# 529.0  0  1
# 564.0  1  0
# 603.0  0  1
#
# [201 rows x 2 columns]

# %%
import pandas as pd
pd.crosstab(df['chest pain'],df['sex'])
# Out:
# sex          0    1
# chest pain
# 1            9   25
# 2           59   97
# 3           52   88
# 4           58  209

# %%
q=df.groupby('c').agg({'age':np.mean})
q
#بر اساس یک متغیر گروه بندی کرده و میانگین سنی اونه ها را داره میده
# Out:
#          age
# c
# 0  49.545455
# 1  53.534694

# %%
df.groupby('chest pain',as_index=True)['c'].mean()
# Out:
# chest pain
# 1    0.323529
# 2    0.108974
# 3    0.207143
# 4    0.704120
# Name: c, dtype: float64

# %%
df.groupby('slope',as_index=False)['c'].mean()
# Out:
#    slope         c
# 0    1.0  0.233766
# 1    2.0  0.705628
# 2    3.0  0.590909

# %%
df.groupby('c').mean()
# Out:
#          age       sex  chest pain  blood pressure          ch  blood sugar  \
# c
# 0  49.545455  0.599432    2.698864      130.039886  241.272455     0.086705
# 1  53.534694  0.848980    3.608163      135.122449  258.929167     0.144033
#
#    electrocardiographic   heart rate  exercise induced  depression      slope  \
# c
# 0               0.511364  151.253561          0.119658     0.387784  1.441026
# 1               0.754098  134.718367          0.595918     1.431837  1.891509
#
#          ca      thal
# c
# 0  0.323171  3.887640
# 1  1.129496  5.900662

# %%
q=df.groupby('c').agg({'age':np.mean,'blood pressure':np.max})
q
# Out:
#          age  blood pressure
# c
# 0  49.545455           190.0
# 1  53.534694           200.0

# %%
q=df.groupby('c').agg({'age':np.mean,'blood pressure':np.max,'c':np.size})
q
# Out:
#          age  blood pressure    c
# c
# 0  49.545455           190.0  352
# 1  53.534694           200.0  245

# %%
q=df.groupby(['c','sex']).agg({'age':np.mean})
q
#روی ستون بیماری و جنسیت گروه بندی می کنم و میانگین سنی را بگیرم
# Out:
#              age
# c sex
# 0 0    51.035461
#   1    48.549763
# 1 0    55.918919
#   1    53.110577

# %%
import pandas as pd
pd.pivot_table(df,index='chest pain',columns='sex',aggfunc=np.mean)
# Out:
#                   age            blood pressure             blood sugar  \
# sex                 0          1              0           1           0
# chest pain
# 1           53.333333  52.440000     141.111111  136.800000    0.111111
# 2           49.152542  47.443299     128.000000  131.144330    0.071429
# 3           52.750000  50.761364     128.673077  132.568182    0.098039
# 4           54.172414  52.205742     137.086207  132.086124    0.103448
#
#                              c                  ca            ...  \
# sex                1         0         1         0         1  ...
# chest pain                                                    ...
# 1           0.200000  0.000000  0.440000  0.500000  0.473684  ...
# 2           0.072165  0.067797  0.134021  0.555556  0.218750  ...
# 3           0.172414  0.096154  0.272727  0.257143  0.612245  ...
# 4           0.106796  0.482759  0.765550  1.000000  0.971429  ...
#
# ...

# %%
pd.pivot_table(df,index='blood pressure',columns='sex',values="age")
# Out:
# sex                     0          1
# blood pressure
# 92.0                  NaN  38.000000
# 94.0            39.000000  51.000000
# 98.0                  NaN  34.000000
# 100.0           41.250000  55.500000
# 101.0                 NaN  46.000000
# 102.0           51.000000        NaN
# 104.0                 NaN  45.000000
# 105.0           39.666667  58.000000
# 106.0           67.000000  48.000000
# 108.0           52.250000  51.000000
# 110.0           50.900000  47.133333
# 112.0           52.333333  48.555556
# 113.0           53.000000        NaN
# 114.0                 NaN  58.000000
# 115.0           54.500000  45.666667
# 117.0                 NaN  60.000000
# 118.0           39.000000  45.714286
# 120.0           49.500000  47.875000
# 122.0           49.000000  46.250000
# 123.0                 NaN  53.000000
# 124.0           58.000000  52.000000
# 125.0           46.500000  55.352941
# 126.0           41.000000  47.000000
# 128.0           55.000000  54.900000
# ...

# %% [markdown]
# # Step 3:Duplicates remove

# %%
df_dup=df.drop_duplicates()
print(df.shape,df_dup.shape)
#یک سطر تکراری داشتیم که اون رو حذف کردیم
# Out:
# (597, 14) (596, 14)

# %%
df_dub=df.drop_duplicates(subset=['sex','chest pain','c','ca'])
print (df.shape,df_dub.shape)

#داده های تکراری در ستونهای گفته شده را حذف کنیم
# Out:
# (597, 14) (58, 14)

# %% [markdown]
# # Step4: Missing values management

# %%
# برای پیدا کردن تعداد میسینگ ولیو در هر ستون داده

df.isnull().sum()
# Out:
# Age (age in year)          0
# sex                        0
# chest pain                 0
# blood pressure             1
# cholestoral               23
# blood sugar                8
# electrocardiographic       1
# heart rate                 1
# exercise induced           1
# depression                 0
# slope                    190
# ca                       294
# thal                     268
# c                          0
# dtype: int64

# %%
import numpy as np
df.replace('?',np.nan)
df.head()
# Out:
#    Age (age in year)  sex  chest pain  blood pressure  cholestoral   \
# 0                 63    1           1           145.0         233.0
# 1                 37    1           3           130.0         250.0
# 2                 41    0           2           130.0         204.0
# 3                 56    1           2           120.0         236.0
# 4                 57    0           4           120.0         354.0
#
#    blood sugar  electrocardiographic   heart rate  exercise induced  \
# 0          1.0                    2.0       150.0               0.0
# 1          0.0                    0.0       187.0               0.0
# 2          0.0                    2.0       172.0               0.0
# 3          0.0                    0.0       178.0               0.0
# 4          0.0                    0.0       163.0               1.0
#
#    depression   slope   ca  thal  c
# 0          2.3    3.0  0.0   6.0  0
# 1          3.5    3.0  0.0   3.0  0
# ...

# %%
df_na=df.dropna(axis=1)          
print(df.shape,df_na.shape)


 #ستون هایی که داده میس دارد را حذف می کند
# Out:
# (597, 14) (597, 5)

# %%
df_na=df.dropna(thresh=500,axis=1)    
print(df.shape, df_na.shape)


#ستون هایی که بیش از 97 داده آن وجود ندارد حذف کن
# Out:
# (597, 14) (597, 11)

# %%
df_na=df.dropna(thresh=12,axis=0)
print(df.shape,df_na.shape) 


 # ردیف هایی که بیش از 2 ستونش میس هست حذف کن
# Out:
# (597, 14) (415, 14)

# %%
df_na=df.fillna(0)
df_na
# Out:
#      Age (age in year)  sex  chest pain  blood pressure  cholestoral   \
# 0                   63    1           1           145.0         233.0
# 1                   37    1           3           130.0         250.0
# 2                   41    0           2           130.0         204.0
# 3                   56    1           2           120.0         236.0
# 4                   57    0           4           120.0         354.0
# ..                 ...  ...         ...             ...           ...
# 592                 52    1           4           140.0         266.0
# 593                 43    1           4           140.0         288.0
# 594                 41    1           4           120.0         336.0
# 595                 44    1           4           135.0         491.0
# 596                 49    1           4           150.0         222.0
#
#      blood sugar  electrocardiographic   heart rate  exercise induced  \
# ...

# %%
df.fillna({'ch':0,'electrocardiographic':1,'depression':2.5})
df
# Out:
#      Age (age in year)  sex  chest pain  blood pressure  cholestoral   \
# 0                   63    1           1           145.0         233.0
# 1                   37    1           3           130.0         250.0
# 2                   41    0           2           130.0         204.0
# 3                   56    1           2           120.0         236.0
# 4                   57    0           4           120.0         354.0
# ..                 ...  ...         ...             ...           ...
# 592                 52    1           4           140.0         266.0
# 593                 43    1           4           140.0         288.0
# 594                 41    1           4           120.0         336.0
# 595                 44    1           4           135.0         491.0
# 596                 49    1           4           150.0         222.0
#
#      blood sugar  electrocardiographic   heart rate  exercise induced  \
# ...

# %%
df_na=df.fillna(df.mode())
df_na
# Out:
#      Age (age in year)  sex  chest pain  blood pressure  cholestoral   \
# 0                   63    1           1           145.0         233.0
# 1                   37    1           3           130.0         250.0
# 2                   41    0           2           130.0         204.0
# 3                   56    1           2           120.0         236.0
# 4                   57    0           4           120.0         354.0
# ..                 ...  ...         ...             ...           ...
# 592                 52    1           4           140.0         266.0
# 593                 43    1           4           140.0         288.0
# 594                 41    1           4           120.0         336.0
# 595                 44    1           4           135.0         491.0
# 596                 49    1           4           150.0         222.0
#
#      blood sugar  electrocardiographic   heart rate  exercise induced  \
# ...

# %%
df_na=df.ffill()      
df_na

#عین داده بعدی را به جای میسینگ قرار دهد
# Out:
#      Age (age in year)  sex  chest pain  blood pressure  cholestoral   \
# 0                   63    1           1           145.0         233.0
# 1                   37    1           3           130.0         250.0
# 2                   41    0           2           130.0         204.0
# 3                   56    1           2           120.0         236.0
# 4                   57    0           4           120.0         354.0
# ..                 ...  ...         ...             ...           ...
# 592                 52    1           4           140.0         266.0
# 593                 43    1           4           140.0         288.0
# 594                 41    1           4           120.0         336.0
# 595                 44    1           4           135.0         491.0
# 596                 49    1           4           150.0         222.0
#
#      blood sugar  electrocardiographic   heart rate  exercise induced  \
# ...

# %%
df_na=df.bfill()
df_na     


  #عین داده قبلی را قرار دهد
# Out:
#      age  sex  chest pain  blood pressure     ch  blood sugar  \
# 0     63    1           1           145.0  233.0          1.0
# 1     37    1           3           130.0  250.0          0.0
# 2     41    0           2           130.0  204.0          0.0
# 3     56    1           2           120.0  236.0          0.0
# 4     57    0           4           120.0  354.0          0.0
# ..   ...  ...         ...             ...    ...          ...
# 592   52    1           4           140.0  266.0          0.0
# 593   43    1           4           140.0  288.0          0.0
# 594   41    1           4           120.0  336.0          0.0
# 595   44    1           4           135.0  491.0          0.0
# 596   49    1           4           150.0  222.0          0.0
#
#      electrocardiographic   heart rate  exercise induced  depression   slope  \
# 0                      2.0       150.0               0.0          2.3    3.0
# ...

# %%
df_new=df.fillna(df.mean())   
df_new
#به شرط اینکه همه داده ها و ویژگی ها را نرمالیزه کرده باشیم
# Out:
#      Age (age in year)  sex  chest pain  blood pressure  cholestoral   \
# 0                   63    1           1           145.0         233.0
# 1                   37    1           3           130.0         250.0
# 2                   41    0           2           130.0         204.0
# 3                   56    1           2           120.0         236.0
# 4                   57    0           4           120.0         354.0
# ..                 ...  ...         ...             ...           ...
# 592                 52    1           4           140.0         266.0
# 593                 43    1           4           140.0         288.0
# 594                 41    1           4           120.0         336.0
# 595                 44    1           4           135.0         491.0
# 596                 49    1           4           150.0         222.0
#
#      blood sugar  electrocardiographic   heart rate  exercise induced  \
# ...

# %%
df_new.isnull(). sum()
# Out:
# Age (age in year)        0
# sex                      0
# chest pain               0
# blood pressure           0
# cholestoral              0
# blood sugar              0
# electrocardiographic     0
# heart rate               0
# exercise induced         0
# depression               0
# slope                    0
# ca                       0
# thal                     0
# c                        0
# dtype: int64

# %% [markdown]
# # Step 5:Outlier Detection

# %%
((df['age']- df['age'].mean())/ df['age'].std()).abs()   #تبدیل به نرمال استاندارد
# Out:
# 0      1.302286
# 1      1.562928
# 2      1.122126
# 3      0.530882
# 4      0.641083
#          ...
# 592    0.090080
# 593    0.901725
# 594    1.122126
# 595    0.791524
# 596    0.240521
# Name: age, Length: 597, dtype: float64

# %%
df_o=df[((df['age']- df['age'].mean())/df['age'].std()).abs()<-3]

print(df.shape,df_o.shape)
# Out:
# (597, 14) (0, 14)

# %%
df_o=df[((df['age']- df['age'].mean())/df['age'].std()).abs()>3]

print(df.shape,df_o.shape)
# Out:
# (597, 14) (0, 14)

# %%
df_o=df[((df['ch']- df['ch'].mean())/df['ch'].std()).abs()<3]

print(df.shape,df_o.shape)

#حداقل 30 مورد داده پرت داشتیم
# Out:
# (597, 14) (567, 14)

# %%
df_o=df[((df['ch']- df['ch'].mean())/df['ch'].std()).abs()>3]

print(df.shape,df_o.shape)
# Out:
# (597, 14) (7, 14)

# %%
df_o=df[((df['ch']- df['ch'].mean())/df['ch'].std()).abs()<-3]

print(df.shape,df_o.shape)
# Out:
# (597, 14) (0, 14)

# %% [markdown]
# # Step 6: Normalization & Standardization(Class Assignment)

# %%
Normalized.to_csv('D:/3rd Session/Normalized.csv', index=False)

# %% [markdown]
# # One Hot Encoding Vs Dummies Encoding (Note book)

# %% [markdown]
# # Step 7: Dummy variables

# %%
# Creating Dummy Variables
chest_pain=pd.get_dummies(df['chest pain'],prefix='chest pain',drop_first=True)
df=pd.concat([df,chest_pain],axis=1)
df.drop(['chest pain'],axis=1,inplace=True)
sp=pd.get_dummies(df['slope'],prefix='slope')
th=pd.get_dummies(df['thal'],prefix='thal')
frames=[df,sp,th]
df=pd.concat(frames,axis=1)
df.drop(['slope','thal'],axis=1,inplace=True)

# %%
df.head(5)
# Out:
#    age  sex  blood pressure     ch  blood sugar  electrocardiographic   \
# 0   63    1           145.0  233.0          1.0                    2.0
# 1   37    1           130.0  250.0          0.0                    0.0
# 2   41    0           130.0  204.0          0.0                    2.0
# 3   56    1           120.0  236.0          0.0                    0.0
# 4   57    0           120.0  354.0          0.0                    0.0
#
#    heart rate  exercise induced  depression    ca  ...  chest pain_4  \
# 0       150.0               0.0          2.3  0.0  ...             0
# 1       187.0               0.0          3.5  0.0  ...             0
# 2       172.0               0.0          1.4  0.0  ...             0
# 3       178.0               0.0          0.8  0.0  ...             0
# 4       163.0               1.0          0.6  0.0  ...             1
#
#    chest pain_2  chest pain_3  chest pain_4  slope_1.0  slope_2.0  slope_3.0  \
# ...
